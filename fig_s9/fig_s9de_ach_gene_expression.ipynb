# %%
from cnmf import cNMF
import numpy as np
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt
import orthodb
import pycurl
from io import BytesIO
import json
import re
from collections import Counter
from sklearn.metrics import r2_score
import seaborn as sns

# %%
neuron_mca_directory = "neuron_cell_counts.h5ad"
palp_directory = "t005.h5ad"

# %%
neurons = sc.read_h5ad(neuron_mca_directory)
palp_cells = sc.read_h5ad(palp_directory)

# %%
palp_neurons = (palp_cells.obs['annotation'] == 'Neuron, A cell (Gr1)') | ((palp_cells.obs['annotation'] == 'Neuron, B cell (Or8)') | (palp_cells.obs['annotation'] == 'Neuron, C cell (Or49)'))

# %%
co2_cells = palp_cells[palp_cells.obs['annotation'] == 'Neuron, A cell (Gr1)',]
B_cells = palp_cells[palp_cells.obs['annotation'] == 'Neuron, B cell (Or8)',]
C_cells = palp_cells[palp_cells.obs['annotation'] == 'Neuron, C cell (Or49)',]

# %%
ach_gene_list_palp = ["AAEL010471",
"AAEL010462",
"AAEL024359",
"AAEL021432",
"AAEL000511",
"AAEL004006",
"AAEL004032",
"AAEL021479",
"AAEL012106",
"AAEL018352",
"AAEL008055",
"AAEL007664",
"AAEL010570",
"AAEL018308",
#"AAEL004923",
#"AAEL004935",
"AAEL017181",
"AAEL007832",
#"AAEL021197",
"AAEL022296"]



ach_gene_list_antenna = ["AAEL010471",
"AAEL010462",
"AAEL024359",
"AAEL021432",
"AAEL000511",
"AAEL004006",
"AAEL004032",
"AAEL021479",
"AAEL012106",
"AAEL018352",
"AAEL008055",
"AAEL007664",
"AAEL010570",
"AAEL018308",
"AAEL004923",
"AAEL004935",
"AAEL017181",
"AAEL007832",
#"AAEL021197",
"AAEL022296"]


ach_gene_names_palp = ["ChAT",
"VAChT",
"ChT",
"ace-2",# (true Dm orth.)",
"ace-1",# (insecticide paralog)",
"nAChRα1",
"nAChRα2",
"nAChRα3",
"nAChRα4",
"nAChRα5",
"nAChRα6",#"nAChRα6 (spinosad target)",
"nAChRα7",
"nAChRβ1",
"Dβ2 orth.",# (α-type in Aedes)",
#"Dβ3 orth. A",
#"Dβ3 orth. B",
"mAChR-A",
"mAChR-B",# (paralog 1)",
#"mAChR-B (paralog 2)",
"mAChR-C",# (AAEL022296)"
]



ach_gene_names_antenna = ["ChAT",
"VAChT",
"ChT",
"ace-2",
"ace-1",
"nAChRα1",
"nAChRα2",
"nAChRα3",
"nAChRα4",
"nAChRα5",
"nAChRα6",
"nAChRα7",
"nAChRβ1",
"Dβ2 orth.",
"Dβ3 orth. A",
"Dβ3 orth. B",
"mAChR-A",
"mAChR-B",
#"mAChR-B (paralog 2)",
"mAChR-C"]

# %%
c02_raw_exp = co2_cells[:,ach_gene_list_palp].layers['raw_data'].mean(axis=0)
#c02_raw_exp = c02_raw_exp[order]
b_raw_exp = B_cells[:,ach_gene_list_palp].layers['raw_data'].mean(axis=0)
#b_raw_exp = b_raw_exp[order]
c_raw_exp = C_cells[:,ach_gene_list_palp].layers['raw_data'].mean(axis=0)
#c_raw_exp = c_raw_exp[order]

# %%
co2_exp_per = (co2_cells[:,ach_gene_list_palp].layers['raw_data'] > 1).sum(axis=0)/co2_cells.shape[0]
#co2_exp_per = co2_exp_per[order]
b_exp_per = (B_cells[:,ach_gene_list_palp].layers['raw_data'] > 1).sum(axis=0)/B_cells.shape[0]
#b_exp_per = b_exp_per[order]
c_exp_per = (C_cells[:,ach_gene_list_palp].layers['raw_data'] > 1).sum(axis=0)/C_cells.shape[0]
#c_exp_per = c_exp_per[order]

# %%
palp_raw_exp = palp_cells[palp_neurons,ach_gene_list_palp].layers['raw_data'].mean(axis=0)
#palp_raw_exp = palp_raw_exp[order]

# %%
palp_exp_per = (palp_cells[palp_neurons,ach_gene_list_palp].layers['raw_data'] > 1).sum(axis=0)/758
#palp_exp_per = palp_exp_per[order]

# %%
neuron_raw_exp = neurons[:,ach_gene_list_antenna].layers['raw_data'].mean(axis=0)

# %%
neuron_exp_per = (neurons[:,ach_gene_list_antenna].layers['raw_data'] > 1).sum(axis=0)/neurons.shape[0]

# %%
antenna_df = pd.DataFrame({'cell type': 'antenna neurons',
                           'neurotransmitter': ach_gene_names_antenna,
                           'average transcripts per cell': neuron_raw_exp,
                           'percent of cells': neuron_exp_per*100})

# %%
co2_df = pd.DataFrame({'cell type': 'A cells',
                           'neurotransmitter': ach_gene_names_palp,
                           'average transcripts per cell': c02_raw_exp,
                           'percent of cells': co2_exp_per*100})

b_df = pd.DataFrame({'cell type': 'B cells',
                           'neurotransmitter': ach_gene_names_palp,
                           'average transcripts per cell': b_raw_exp,
                           'percent of cells': b_exp_per*100})

c_df = pd.DataFrame({'cell type': 'C cells',
                           'neurotransmitter': ach_gene_names_palp,
                           'average transcripts per cell': c_raw_exp,
                           'percent of cells': c_exp_per*100})

# %%
palp_df = pd.DataFrame({'cell type': 'palp neurons',
                           'neurotransmitter': ach_gene_names_palp,
                           'average transcripts per cell': palp_raw_exp,
                           'percent of cells': palp_exp_per*100})

# %%
exp_all_cells = pd.concat([co2_df,
                           b_df,
                           c_df,
                           palp_df,
                           antenna_df,
                           ],ignore_index=True)

# %%
bins_5 = [0,
          .5,
          1,
          1.5,
          2,
          2.5,
          3,
          3.5,
          4,
          4.5,
          5,
          max(exp_all_cells['average transcripts per cell'])]
bins_5_labels = ['0','.5','1','1.5','2','2.5','3','3.5','4','4.5','5+']
exp_all_cells['cutoff_5'] = pd.cut(exp_all_cells['average transcripts per cell'], bins_5,labels = bins_5_labels)

# %%
exp_all_cells
# Out:
#           cell type neurotransmitter  average transcripts per cell  \
# 0           A cells             ChAT                      4.718750
# 1           A cells            VAChT                      2.101562
# 2           A cells              ChT                      3.812500
# 3           A cells            ace-2                      6.839844
# 4           A cells            ace-1                     25.828125
# ..              ...              ...                           ...
# 82  antenna neurons      Dβ3 orth. A                      0.001444
# 83  antenna neurons      Dβ3 orth. B                      0.000674
# 84  antenna neurons          mAChR-A                      0.025989
# 85  antenna neurons          mAChR-B                      0.012995
# 86  antenna neurons          mAChR-C                      0.012995
#
#     percent of cells cutoff_5
# 0          85.546875      4.5
# 1          56.250000        2
# 2          76.953125      3.5
# 3          89.843750       5+
# 4          97.265625       5+
# ..               ...      ...
# 82          0.009626        0
# 83          0.000000        0
# 84          0.105881        0
# 85          0.134758        0
# 86          0.115507        0
#
# [87 rows x 5 columns]

# %%
custom_palette =sns.cubehelix_palette(start = 2, rot= 0, n_colors=11)

# %%
custom_palette
# Out:
# [[0.7764338074668017, 0.8982145133398445, 0.8009415971088042],
#  [0.6796466875702348, 0.8442263851507816, 0.7127675713648596],
#  [0.5887177033611721, 0.7865264317705264, 0.6285257720569012],
#  [0.5036468548396135, 0.7251146531990786, 0.5482161991849287],
#  [0.4244341420055591, 0.6599910494364387, 0.4718388527489426],
#  [0.3550011334864599, 0.5950771891100572, 0.4033153013763936],
#  [0.2871792400447748, 0.5227361474756544, 0.33458395078815834],
#  [0.2252154822905939, 0.4466832806500591, 0.2697848266359092],
#  [0.1691098602239171, 0.3669185886332714, 0.20891792891964617],
#  [0.11886237384474461, 0.28344207142529143, 0.15198325763936943],
#  [0.07447302315307625, 0.19625372902611904, 0.09898081279507877]]

# %%
ax = sns.relplot(exp_all_cells,y='neurotransmitter',x='cell type',hue='cutoff_5',size='percent of cells',height=7.0, aspect=.75,
                 palette= custom_palette,sizes=(5,300))#gridspec_kws={})
ax.tick_params(axis='x', rotation=60)

#plt.tight_layout()
#plt.margins(x=0.02)
plt.xlabel('Cell type')
plt.ylabel('ACh associated gene')
plt.savefig('ach_assoc_gene_5_w_legend.svg')
plt.show()

#ax.set_xticklabels(locs=[1,3,4,5,6],labels=['a','b','c','d','e'])
#ax.set_xticklabels()
